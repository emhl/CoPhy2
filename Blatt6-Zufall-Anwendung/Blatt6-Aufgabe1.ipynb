# %% [markdown]
# # Blatt 6

# %% [markdown]
# ## Aufgabe 1 Zufallszahlentests

# %% [markdown]
# Betrachte die folgenden (Pseudo-)Zufallszahlengeneratoren
#
# (A) Linearer Kongruenzgenerator
# $x_{n+1} = (a x_n + b) \mod m$
# mit m = 231,a = 65539,b = 0 (RANDU).
#
# (B) Linearer Kongruenzgenerator
# mit m = 231,a = 1103515245,b = 12345 (GLIBC).
#
# (C) Nachkommastellen von π.
# Hinweis:
# ```python
# from sympy.mpmath import mp
# N=1000 # number of digits
# mp.dps = N
# s = str(mp.pi)
# for i in range(2,N):
#     print s[i]
# ```
#
# (D) Der Standard-PRNG von Python (random()).
#
#
# Der Startwert (SEED) kann frei gew ̈ahlt werden.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpmath import mp
import random

# %%
# Linearer Kongruenzgenerator
def lcg(m, a, b, x0, n):
    x = x0
    y = np.zeros(n)
    for i in range(n):
        x = (a*x + b) % m
        y[i] = x
    return y

def rand_a(n, seed=1):
    m = 2**32
    a = 65539
    b = 0
    x0 = seed
    return lcg(m, a, b, x0, n)

def rand_b(n, seed=1):
    m = 2**32
    a = 1103515245
    b = 12345
    x0 = seed
    return lcg(m, a, b, x0, n)

def rand_c(n):
    mp.dps = n
    s = str(mp.pi)
    y = np.zeros(n)
    for i in range(2,n):
        y[i] = int(s[i])
    return y

def rand_d(n):
    y = np.zeros(n)
    for i in range(n):
        y[i] = random.random()
    return y

# %% [markdown]
# ### a) Bestimme f ̈ur alle PRNGs N = 10^4 Zufallszahlen
# in drei Spalten und plotte diese
# dreidimensional (”Parking-Lot”- bzw. Spektraltest). Bei welchen PRNGs erkennt man
# durch Drehung des Plots Hyperebenenverhalten?

# %%
n, seed = 1000, 420

plt.scatter(range(n),rand_a(n,seed),s=10)
plt.scatter(range(n),rand_b(n,seed),s=10)

# %%
plt.scatter(range(n),rand_c(n),s=5)

# %%
plt.scatter(range(n),rand_d(n),s=10)
